# %% [markdown]
# ## Generate training data with dataset_gen

# %%
#!python /kaggle/input/datasets/johnjg75/qrlocator-py/dataset_gen.py

# !python /kaggle/input/datasets/johnjg75/qrlocator-py/interpret.py

# %% [markdown]
# ## Start training!

# %%
#cat /kaggle/input/datasets/johnjg75/qrlocator-py/config.py
# !python /kaggle/input/datasets/johnjg75/qrlocator-py/train_eval.py --mode train
